# %% [markdown]
# # Computer Vision Coursework Submission (IN3060)
#
# **Student name, ID and cohort:** Furqan Faruqui (220023314) - UG

# %% [markdown]
# ### Load packages
#
# In the next cell you should load all the packages required to test your function.

# %%
from Code.models import simple_cnn_model
from Code.utilities import path_retrievers
from Code.mask_detection import MaskDetection
import os

# %% [markdown]
# ### Load model
#
# In the next cell you should load your best performing model (this might consist of more than one file). Avoid to load it within `MaskDetection` to avoid having to reload it each time.

# %%
retriever = path_retrievers.PathRetrievers()
model = simple_cnn_model.SimpleCNNModel()

model_name = 'simple_cnn_model.keras'
save_path = os.path.join(retriever.path_to_export_trained_models, model_name)
model.load_model(save_path)

# %% [markdown]
# # Test MaskDetection
#
# This section should allow to test the `MaskDetection` function. First, add cells with the code needed to load the necessary subroutines to make `MaskDetection` work.

# %%
MaskDetection
# Out:
# Code.mask_detection.MaskDetection

# %% [markdown]
# Then, make a call to the `MaskDetection` function to see what results it produces.

# %%
path_to_test = retriever.path_to_personal_dataset_images
MaskDetection(path_to_test, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
